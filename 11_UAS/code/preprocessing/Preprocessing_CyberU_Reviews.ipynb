# %% [markdown]
# # Text Preprocessing (Clean Data)

# %%
import pandas as pd
import string
import re
df = pd.read_csv('../../dataset/CyberU_reviews.csv')

output_path = '../../dataset/cleaned-data/CyberU_reviews_cleaned.csv'

df.head()
# Out:
#    page               name                                               link  \
# 0     1  Mahasiswa Pelajar  https://www.google.com/maps/contrib/1125439316...
# 1     1       Fathia Rizky  https://www.google.com/maps/contrib/1036827544...
# 2     1    Michael Sitorus  https://www.google.com/maps/contrib/1149239308...
# 3     1    Malinda Malinda  https://www.google.com/maps/contrib/1027179724...
# 4     1      Yudi Mulyawan  https://www.google.com/maps/contrib/1022158108...
#
#                                            thumbnail  rating           date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjVjy...     5.0  seminggu lalu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjXng...     5.0  2 minggu lalu
# 2  https://lh3.googleusercontent.com/a-/ALV-UjVv9...     5.0   setahun lalu
# 3  https://lh3.googleusercontent.com/a-/ALV-UjVeh...     5.0  2 minggu lalu
# 4  https://lh3.googleusercontent.com/a-/ALV-UjWFg...     5.0   setahun lalu
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                               images local_guide
# 0                                                NaN         NaN
# 1                                                NaN        True
# 2  ['https://lh5.googleusercontent.com/p/AF1QipPj...        True
# 3                                                NaN        True
# 4                                                NaN         NaN

# %%
# drop the columns
df = df.drop(columns=['page', 'link', 'thumbnail', 'date', 'images', 'local_guide'], axis=1)
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...

# %% [markdown]
# ## Convert to lowercase

# %%
df['clean_text'] = df['snippet'].str.lower()
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen universitas siber indonesia, berpe...
# 4  kampus saya makin keren aja,\n😁, sebagai angka...

# %% [markdown]
# ## Remove Missings Values

# %%
df.isnull().sum()
# Out:
# name           0
# rating         0
# snippet       38
# clean_text    38
# dtype: int64

# %%
df = df.dropna(subset=['clean_text'])
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen universitas siber indonesia, berpe...
# 4  kampus saya makin keren aja,\n😁, sebagai angka...

# %%
df.isnull().sum()
# Out:
# name          0
# rating        0
# snippet       0
# clean_text    0
# dtype: int64

# %% [markdown]
# ## Menghapus Whitespace

# %%
def remove_extra_whitespace(text):
    # Menghapus spasi di awal dan akhir teks
    text = text.strip()
    # Menghapus spasi berlebih di tengah teks
    text = re.sub('\s+', ' ', text)
    return text

# Menerapkan fungsi pada kolom 'clean_text'
df['clean_text'] = df['clean_text'].apply(lambda x: remove_extra_whitespace(x))
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_30212\1765752112.py:5: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐ ac nya masyaallah dingin b...
# 2  kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen universitas siber indonesia, berpe...
# 4  kampus saya makin keren aja, 😁, sebagai angkat...

# %% [markdown]
# ## Removal of Punctuations

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    punctuations = string.punctuation
    return text.translate(str.maketrans('', '', punctuations))

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: remove_punctuations(x))
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis 1 menit keluar tol ...
# 1  fasilitas nya ⭐⭐⭐⭐⭐ ac nya masyaallah dingin b...
# 2  kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus saya makin keren aja 😁 sebagai angkatan...

# %% [markdown]
# ## Normalisasi Teks

# %%
# Kamus slang dan kata yang sudah dinormalisasi
slang_dict = {
    "gak": "tidak",
    "u": "you",
    "yg": "yang",
    "kalo": "kalau",
    "aja": "saja",
    "tdk": "tidak",
    "bgt": "banget",
    "dgn": "dengan",
    "dr": "dari",
    "dlm": "dalam",
    "sbg": "sebagai",
    "spt": "seperti",
    "utk": "untuk",
    "krn": "karena",
    "tp": "tapi",
    "jd": "jadi",
    "sy": "saya",
    "dg": "dengan",
    "trs": "terus",
    "sm": "sama",
    "pd": "pada",
    "blm": "belum",
    "sdh": "sudah",
    "td": "tadi",
    "lg": "lagi",
    "gmn": "gimana",
    "knp": "kenapa",
    "dpt": "dapat",
    "bbrp": "beberapa",
    "dl": "dulu",
    "kl": "kalau",
    "tmn": "teman",
    "msh": "masih",
    "syg": "sayang",
    "cm": "cuma",
    "bs": "bisa",
    "jg": "juga",
    "org": "orang",
    "bkn": "bukan",
    "bbrp": "beberapa",
    "dpt": "dapat",
    "dgn": "dengan",
    "dr": "dari",
    "gmn": "gimana",
    "hrs": "harus",
    "jgn": "jangan",
    "krn": "karena",
    "lg": "lagi",
    "pd": "pada",
    "sdh": "sudah",
    "sm": "sama",
    "tdk": "tidak",
    "tp": "tapi",
    "utk": "untuk",
    "yg": "yang"
}

# Fungsi untuk mengganti kata slang dengan kata yang sudah dinormalisasi
def normalize_text(text):
    words = text.split()
    normalized_words = [slang_dict.get(word, word) for word in words]
    return " ".join(normalized_words)

# Menerapkan normalisasi pada kolom clean_text
df['clean_text'] = df['clean_text'].apply(lambda x: normalize_text(x))
df.head(10)
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
# 5           Nur Raly     5.0
# 6   Hendra Rudystira     5.0
# 7           Palupi R     5.0
# 8    Andreas Wardoyo     5.0
# 9      Desvika Elsar     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
# 5  Pengajar yg bepengalam, kampus yg nyaman, biay...
# 6  Berawal dari BRI Institute, menjadikan Cyber U...
# 7      ternyata ada kampus bagus di TB Simatupang...
# 8                                        Baik sekali
# 9  Kampusnya sangat nyaman terutama di perpusnya,...
#
#                                           clean_text
# 0  lokasi kampusnya strategis 1 menit keluar tol ...
# 1  fasilitas nya ⭐⭐⭐⭐⭐ ac nya masyaallah dingin b...
# 2  kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus saya makin keren saja 😁 sebagai angkata...
# 5  pengajar yang bepengalam kampus yang nyaman bi...
# 6  berawal dari bri institute menjadikan cyber un...
# 7         ternyata ada kampus bagus di tb simatupang
# 8                                        baik sekali
# 9  kampusnya sangat nyaman terutama di perpusnya ...

# %% [markdown]
# ## Removal of Stopwords

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('indonesian'))
# Out:
# 'ada, adalah, adanya, adapun, agak, agaknya, agar, akan, akankah, akhir, akhiri, akhirnya, aku, akulah, amat, amatlah, anda, andalah, antar, antara, antaranya, apa, apaan, apabila, apakah, apalagi, apatah, artinya, asal, asalkan, atas, atau, ataukah, ataupun, awal, awalnya, bagai, bagaikan, bagaimana, bagaimanakah, bagaimanapun, bagi, bagian, bahkan, bahwa, bahwasanya, baik, bakal, bakalan, balik, banyak, bapak, baru, bawah, beberapa, begini, beginian, beginikah, beginilah, begitu, begitukah, begitulah, begitupun, bekerja, belakang, belakangan, belum, belumlah, benar, benarkah, benarlah, berada, berakhir, berakhirlah, berakhirnya, berapa, berapakah, berapalah, berapapun, berarti, berawal, berbagai, berdatangan, beri, berikan, berikut, berikutnya, berjumlah, berkali-kali, berkata, berkehendak, berkeinginan, berkenaan, berlainan, berlalu, berlangsung, berlebihan, bermacam, bermacam-macam, bermaksud, bermula, bersama, bersama-sama, bersiap, bersiap-siap, bertanya, bertanya-tanya, berturut, berturut-turut, bertutur, berujar, berupa, besar, betul, betulkah, biasa, biasanya, bila, bilakah, bisa, bisakah, boleh, bolehkah, bolehlah, buat, bukan, bukankah, bukanlah, bukannya, bulan, bung, cara, caranya, cukup, cukupkah, cukuplah, cuma, dahulu, dalam, dan, dapat, dari, daripada, datang, dekat, demi, demikian, demikianlah, dengan, depan, di, dia, diakhiri, diakhirinya, dialah, diantara, diantaranya, diberi, diberikan, diberikannya, dibuat, dibuatnya, didapat, didatangkan, digunakan, diibaratkan, diibaratkannya, diingat, diingatkan, diinginkan, dijawab, dijelaskan, dijelaskannya, dikarenakan, dikatakan, dikatakannya, dikerjakan, diketahui, diketahuinya, dikira, dilakukan, dilalui, dilihat, dimaksud, dimaksudkan, dimaksudkannya, dimaksudnya, diminta, dimintai, dimisalkan, dimulai, dimulailah, dimulainya, dimungkinkan, dini, dipastikan, diperbuat, diperbuatnya, dipergunakan, diperkirakan, diperlihatkan, diperlukan, diperlukannya, dipersoalkan, dipertanyakan, dipunyai, diri, dirinya, disampaikan, disebut, disebutkan, disebutkannya, disini, disinilah, ditambahkan, ditandaskan, ditanya, ditanyai, ditanyakan, ditegaskan, ditujukan, ditunjuk, ditunjuki, ditunjukkan, ditunjukkannya, ditunjuknya, dituturkan, dituturkannya, diucapkan, diucapkannya, diungkapkan, dong, dua, dulu, empat, enggak, enggaknya, entah, entahlah, guna, gunakan, hal, hampir, hanya, hanyalah, hari, harus, haruslah, harusnya, hendak, hendaklah, hendaknya, hingga, ia, ialah, ibarat, ibaratkan, ibaratnya, ibu, ikut, ingat, ingat-ingat, ingin, inginkah, inginkan, ini, inikah, inilah, itu, itukah, itulah, jadi, jadilah, jadinya, jangan, jangankan, janganlah, jauh, jawab, jawaban, jawabnya, jelas, jelaskan, jelaslah, jelasnya, jika, jikalau, juga, jumlah, jumlahnya, justru, kala, kalau, kalaulah, kalaupun, kalian, kami, kamilah, kamu, kamulah, kan, kapan, kapankah, kapanpun, karena, karenanya, kasus, kata, katakan, katakanlah, katanya, ke, keadaan, kebetulan, kecil, kedua, keduanya, keinginan, kelamaan, kelihatan, kelihatannya, kelima, keluar, kembali, kemudian, kemungkinan, kemungkinannya, kenapa, kepada, kepadanya, kesampaian, keseluruhan, keseluruhannya, keterlaluan, ketika, khususnya, kini, kinilah, kira, kira-kira, kiranya, kita, kitalah, kok, kurang, lagi, lagian, lah, lain, lainnya, lalu, lama, lamanya, lanjut, lanjutnya, lebih, lewat, lima, luar, macam, maka, makanya, makin, malah, malahan, mampu, mampukah, mana, manakala, manalagi, masa, masalah, masalahnya, masih, masihkah, masing, masing-masing, mau, maupun, melainkan, melakukan, melalui, melihat, melihatnya, memang, memastikan, memberi, memberikan, membuat, memerlukan, memihak, meminta, memintakan, memisalkan, memperbuat, mempergunakan, memperkirakan, memperlihatkan, mempersiapkan, mempersoalkan, mempertanyakan, mempunyai, memulai, memungkinkan, menaiki, menambahkan, menandaskan, menanti, menanti-nanti, menantikan, menanya, menanyai, menanyakan, mendapat, mendapatkan, mendatang, mendatangi, mendatangkan, menegaskan, meng ...

# %%
from nltk.corpus import stopwords

STOPWORDS = set(stopwords.words('indonesian'))
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1  fasilitas nya ⭐⭐⭐⭐⭐ ac nya masyaallah dingin b...
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren 😁 angkatan lulus semoga adek kela...

# %% [markdown]
# ## !!!Removal of Frequent Words

# %%
# Menghapus semua kata "nya" yang berdiri sendiri dalam kolom clean_text
df['clean_text'] = df['clean_text'].apply(lambda text: ' '.join([word for word in text.split() if word != 'nya']))

df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1      fasilitas ⭐⭐⭐⭐⭐ ac masyaallah dingin banget 🥶
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren 😁 angkatan lulus semoga adek kela...

# %%
from collections import Counter
word_count = Counter()
for text in df['clean_text']:
    for word in text.split():
        word_count[word] += 1
        
word_count.most_common(10)
# Out:
# [('kampus', 14),
#  ('keren', 11),
#  ('kampusnya', 8),
#  ('dosen', 7),
#  ('nyaman', 7),
#  ('strategis', 6),
#  ('lokasi', 4),
#  ('bagus', 4),
#  ('cyber', 3),
#  ('university', 3)]

# %%
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1      fasilitas ⭐⭐⭐⭐⭐ ac masyaallah dingin banget 🥶
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren 😁 angkatan lulus semoga adek kela...

# %%
# FREQUENT_WORDS = set(word for (word, wc) in word_count.most_common(3))
# def remove_freq_words(text):
#     return " ".join([word for word in text.split() if word not in FREQUENT_WORDS])

# %%
# df['clean_text'] = df['clean_text'].apply(lambda x: remove_freq_words(x))
# df.head()

# %% [markdown]
# ## Removal of Rare Words

# %%
# This cell should be moved after CELL INDEX 22
RARE_WORDS = set(word for (word, wc) in word_count.most_common()[:-10:-1])
print(RARE_WORDS)
# Out:
# {'be', 'we', 'campoes', 'in', 'smart', 'fintech', 'wish', 'nice', 'will'}

# %%
def remove_rare_words(text):
    return " ".join([word for word in text.split() if word not in RARE_WORDS])

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: remove_rare_words(x))
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1      fasilitas ⭐⭐⭐⭐⭐ ac masyaallah dingin banget 🥶
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren 😁 angkatan lulus semoga adek kela...

# %% [markdown]
# ## Removal of Special characters

# %%
import re
def remove_spl_chars(text):
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_30212\688201358.py:4: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: remove_spl_chars(x))
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1             fasilitas ac masyaallah dingin banget
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren angkatan lulus semoga adek kelas ...

# %% [markdown]
# ## Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Membuat stemmer bahasa Indonesia
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi stemming
def stem_words(text):
    return stemmer.stem(text)

# %%
# Menerapkan stemming pada kolom clean_text
df['stemmed_text'] = df['clean_text'].apply(lambda x: stem_words(x))
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text  \
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1             fasilitas ac masyaallah dingin banget
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren angkatan lulus semoga adek kelas ...
#
#                                         stemmed_text
# 0  lokasi kampus strategis 1 menit tol pasar ming...
# 1              fasilitas ac masyaallah dingin banget
# 2  kampus cocok era digitalisasi milenial kampus ...
# 3       dosen dosen universitas siber indonesia alam
# 4  kampus keren angkat lulus moga adek kelas dose...

# %% [markdown]
# ## Lemmatization & POS Tagging

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}

def lemmatize_words(text):
    # find pos tags
    pos_text = pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])

# %%
from nltk.corpus import wordnet

wordnet.NOUN
# Out:
# 'n'

# %%
# import nltk
# nltk.download('averaged_perceptron_tagger')

# df['lemmatized_text'] = df['clean_text'].apply(lambda x: lemmatize_words(x))
# df.head()

# %%
df.sample(frac=1).head(10)
# Out:
#                        name  rating  \
# 3           Malinda Malinda     5.0
# 27            Putri Artanti     5.0
# 20  Gunawan Witjaksono, PhD     5.0
# 18           Safrilla Bagas     5.0
# 16        Arisena Hendrawan     5.0
# 39            Ninuk Wiliani     5.0
# 8           Andreas Wardoyo     5.0
# 2           Michael Sitorus     5.0
# 26            Kastin Tinara     5.0
# 7                  Palupi R     5.0
#
#                                               snippet  \
# 3   dosen dosen Universitas Siber Indonesia, berpe...
# 27                   kampus dengan akses sangat mudah
# 20                 Kampusnya keren dan mudah aksesnya
# 18               Lokasi kampus nya sangat strategis👍👍
# 16  Dosen muda yang punya pengalaman bidang IT, ek...
# 39                                               nice
# 8                                         Baik sekali
# 2   Kampus yang cocok untuk era digitalisasi dan m...
# 26                                Kampusnya kerenn 👍👍
# 7       ternyata ada kampus bagus di TB Simatupang...
#
#                                            clean_text  \
# 3   dosen dosen universitas siber indonesia berpen...
# 27                                 kampus akses mudah
# 20                     kampusnya keren mudah aksesnya
# 18                           lokasi kampus strategis
# 16  dosen muda pengalaman bidang it ekonomi kewira...
# 39
# 8
# 2   kampus cocok era digitalisasi milenial kampusn...
# 26                                  kampusnya kerenn
# 7                          kampus bagus tb simatupang
#
#                                          stemmed_text
# 3        dosen dosen universitas siber indonesia alam
# 27                                 kampus akses mudah
# 20                           kampus keren mudah akses
# 18                            lokasi kampus strategis
# 16  dosen muda alam bidang it ekonomi kewirausahaa...
# 39
# 8
# 2   kampus cocok era digitalisasi milenial kampus ...
# 26                                      kampus kerenn
# 7                          kampus bagus tb simatupang

# %% [markdown]
# ## Tokenization

# %%
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text  \
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1             fasilitas ac masyaallah dingin banget
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren angkatan lulus semoga adek kelas ...
#
#                                         stemmed_text
# 0  lokasi kampus strategis 1 menit tol pasar ming...
# 1              fasilitas ac masyaallah dingin banget
# 2  kampus cocok era digitalisasi milenial kampus ...
# 3       dosen dosen universitas siber indonesia alam
# 4  kampus keren angkat lulus moga adek kelas dose...

# %%
df.isnull().sum()
# Out:
# name            0
# rating          0
# snippet         0
# clean_text      0
# stemmed_text    0
# dtype: int64

# %%
from nltk.tokenize import word_tokenize

# Tokenisasi
df['tokenized_text'] = df['stemmed_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#                 name  rating  \
# 0  Mahasiswa Pelajar     5.0
# 1       Fathia Rizky     5.0
# 2    Michael Sitorus     5.0
# 3    Malinda Malinda     5.0
# 4      Yudi Mulyawan     5.0
#
#                                              snippet  \
# 0  Lokasi Kampusnya strategis, 1 menit keluar tol...
# 1  fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin ...
# 2  Kampus yang cocok untuk era digitalisasi dan m...
# 3  dosen dosen Universitas Siber Indonesia, berpe...
# 4  Kampus saya makin keren aja,\n😁, sebagai angka...
#
#                                           clean_text  \
# 0  lokasi kampusnya strategis 1 menit tol pasar m...
# 1             fasilitas ac masyaallah dingin banget
# 2  kampus cocok era digitalisasi milenial kampusn...
# 3  dosen dosen universitas siber indonesia berpen...
# 4  kampus keren angkatan lulus semoga adek kelas ...
#
#                                         stemmed_text  \
# 0  lokasi kampus strategis 1 menit tol pasar ming...
# 1              fasilitas ac masyaallah dingin banget
# 2  kampus cocok era digitalisasi milenial kampus ...
# 3       dosen dosen universitas siber indonesia alam
# 4  kampus keren angkat lulus moga adek kelas dose...
#
#                                       tokenized_text
# 0  [lokasi, kampus, strategis, 1, menit, tol, pas...
# 1        [fasilitas, ac, masyaallah, dingin, banget]
# 2  [kampus, cocok, era, digitalisasi, milenial, k...
# 3  [dosen, dosen, universitas, siber, indonesia, ...
# 4  [kampus, keren, angkat, lulus, moga, adek, kel...

# %%
df.isnull().sum()
# Out:
# name              0
# rating            0
# snippet           0
# clean_text        0
# stemmed_text      0
# tokenized_text    0
# dtype: int64

# %%
import os

try:
	# Save the dataframe to a CSV file
	df.to_csv(output_path, index=False)
	print(f"DataFrame successfully saved to {output_path}")
except Exception as e:
	print(f"An error occurred: {e}")
# Out:
# DataFrame successfully saved to ../../dataset/cleaned-data/CyberU_reviews_cleaned.csv
